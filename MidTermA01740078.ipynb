# %%
pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 5.6 MB/s
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 8.7 MB/s
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('dataset.xlsx',
                 sheet_name='Hoja5',
                 engine = 'openpyxl',
                )

# %% [markdown]
# Preparamos dataset, eliminando columnas innecesarias y convirtiendo a string y renombrando las que nos serán utiles para las preguntas:

# %%
df.drop(['Pruebas'],
        axis=1,
        inplace=True)

# %%
df.rename(columns = {'Edo.': 'Estado',
                     'Habs': 'Habitantes',
                     'Cont14dias':'Contagios las últimas dos semanas',
                     'Muertes15dias':'Defunciones las últimas dos semanas',
                     'ContTotales':'Contagios Acumulados',
                     'MuertesTotales': 'Defunciones Acumuladas'},
          inplace=True
         )

# %%
df.columns=list(map(str,df.columns))

# %%
df.head(32)
# Out:
#                              Estado  Habitantes  \
# 0                           Durango     1632934
# 1                      Quintana Roo     1325578
# 2                           Chiapas     4796580
# 3                           Morelos     1777227
# 4              Coahuila de Zaragoza     2748391
# 5                          Campeche      822441
# 6                         Zacatecas     1490668
# 7                   Baja California     3155070
# 8                           Yucatán     1955577
# 9                          Guerrero     3388768
# 10                       Tamaulipas     3268554
# 11                          Tabasco     2662480
# 12                        Chihuahua     3406465
# 13                          Nayarit     1084979
# 14                           Colima      650555
# 15              Michoacán de Ocampo     4351037
# 16                  San Luis Potosí     2585518
# 17                         Tlaxcala     1169936
# 18                   Aguascalientes     1184996
# 19              Baja California Sur      637026
# 20                          Jalisco     7350682
# 21                           Sonora     2662480
# 22                          Hidalgo     2665018
# 23                        Querétaro     1827937
# 24                           Oaxaca     3801962
# 25                       Nuevo León     4653458
# 26                          Sinaloa     2767761
# 27                       Guanajuato     5486372
# 28  Veracruz de Ignacio de la Llave     7643194
# 29                           Puebla     5779829
# 30                 Ciudad de México     8851080
# 31                           México    15175862
#
#     Contagios las últimas dos semanas  Defunciones las últimas dos semanas  \
# 0                                 234                                   14
# 1                                 305                                   13
# 2                                 389                                   27
# 3                                 482                                   30
# 4                                 528                                   43
# 5                                 552                                   21
# 6                                 666                                   19
# 7                                 676                                   73
# 8                                 736                                   21
# 9                                 743                                   39
# 10                                803                                   64
# 11                                852                                   48
# 12                                955                                   62
# 13                                959                                   37
# 14                               1002                                   25
# 15                               1070                                   79
# 16                               1130                                   36
# 17                               1262                                   21
# 18                               1461                                   22
# 19                               1475                                   18
# 20                               1549                                  171
# 21                               1564                                   69
# 22                               1669                                   77
# 23                               1719                                   78
# 24                               2098                                   62
# 25                               2118                                   93
# 26                               2264                                   65
# 27                               3087                                   94
# 28                               4172                                  107
# 29                               4393                                   82
# 30                              13540                                  229
# 31                              59540                                 2084
#
#     Contagios Acumulados  Defunciones Acumuladas
# 0                  67564                    3481
# 1                  90999                    4321
# 2                  33617                    2384
# 3                  65844                    5162
# 4                 143460                    8700
# 5                  33309                    2220
# 6                  67067                    3827
# 7                 129391                   12095
# 8                 108277                    6368
# 9                  97186                    6666
# 10                140745                    7884
# 11                189194                    6002
# 12                123384                    9797
# 13                 57541                    3133
# 14                 54094                    2172
# 15                 92732                    8702
# 16                179231                    7393
# 17                 42803                    3051
# 18                 60559                    3455
# 19                100726                    2612
# 20                231229                   19125
# 21                161733                    9952
# 22                 88584                    8295
# 23                139762                    6110
# 24                117040                    6006
# 25                307411                   14825
# 26                119209                    9545
# 27                275296                   14684
# 28                169773                   15886
# 29                166023                   16235
# 30               1356390                   42181
# 31               5534086                  318835

# %% [markdown]
# # 1. Description of the data.
# #### En la tabla anterior se muestra la propagación del COVID-19 en México a través de datos y visualizaciones actualizadas frecuentemente

# %% [markdown]
# # 2. Interesting observations you discovered:
# #### Me llamó la atención de los datos anteriores como muchos de los estados con menor población tuvieron mayor indice de mortalidades, lo que muestra un mal manejo de la pandemia por parte del gobierno

# %% [markdown]
# # 3. Two/Three graphical visualisations illustrating the information you've discovered.
# #### At least one of your two graphs must support what is explained in (2).
# una grafica de pastel con las muertes totales por estado
# y otra... ?

# %% [markdown]
# ## Describir variables
# * `Estado` - Variable de tipo String, que muestra el Estado de la Republica del que se mostraran los datos.
# * `Habitantes:` - Cantidad total de habitantes de dicho estado segun INEGI, hasta el año 2020.
# * `Contagios las últimas dos semanas:`- Por medio de una variable String, se muestran los contagios de COVID19 en los últimos 14 días.
# * `Defunciones las últimas dos semanas`- Esta columna representa los fallecimientos que se han presentado en los últimos 14 días.
# * `Contagios Acumulados`- Podemos observar el total de casos SARS COVID 19 desde el inicio de la pandemia en el estado correspondiente.
# * `Defunciones Acumuladas`- Total de fallecimientos hasta el día de hoy desde Marzo 2019.

# %% [markdown]
# # 4. Questions

# %% [markdown]
# ## Pregunta #1: Como se puede observar la distribución de casos totales en Nuevo Leon desde el inicio de la pandemia comparado con los de Sinaloa?

# %% [markdown]
# Como nuestros datos se basan en un Estado, necesitamos que esta columna sea nuestro index:

# %%
df.set_index('Estado', inplace=True)
df.head(32)
# Out:
#                                  Habitantes  \
# Estado
# Durango                             1632934
# Quintana Roo                        1325578
# Chiapas                             4796580
# Morelos                             1777227
# Coahuila de Zaragoza                2748391
# Campeche                             822441
# Zacatecas                           1490668
# Baja California                     3155070
# Yucatán                             1955577
# Guerrero                            3388768
# Tamaulipas                          3268554
# Tabasco                             2662480
# Chihuahua                           3406465
# Nayarit                             1084979
# Colima                               650555
# Michoacán de Ocampo                 4351037
# San Luis Potosí                     2585518
# Tlaxcala                            1169936
# Aguascalientes                      1184996
# Baja California Sur                  637026
# Jalisco                             7350682
# Sonora                              2662480
# Hidalgo                             2665018
# Querétaro                           1827937
# Oaxaca                              3801962
# Nuevo León                          4653458
# Sinaloa                             2767761
# Guanajuato                          5486372
# Veracruz de Ignacio de la Llave     7643194
# Puebla                              5779829
# Ciudad de México                    8851080
# México                             15175862
#
#                                  Contagios las últimas dos semanas  \
# Estado
# Ubicamos Nuevo Leon y Sinaloa dentro de todos los estados:

# %%
df.loc['Nuevo León',:]
# Out:
# Habitantes                             4653458
# Contagios las últimas dos semanas         2118
# Defunciones las últimas dos semanas         93
# Contagios Acumulados                    307411
# Defunciones Acumuladas                   14825
# Name: Nuevo León, dtype: int64

# %%
df.loc['Sinaloa',:]
# Out:
# Habitantes                             2767761
# Contagios las últimas dos semanas         2264
# Defunciones las últimas dos semanas         65
# Contagios Acumulados                    119209
# Defunciones Acumuladas                    9545
# Name: Sinaloa, dtype: int64

# %% [markdown]
# Graficamos los datos anteriores:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Elegir estilo de la grafica

# %%
print(mpl.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
mpl.style.use('tableau-colorblind10')

# %%
ci=df.loc[['Nuevo León','Sinaloa'],'Contagios Acumulados':].transpose()
ci.plot()
plt.ylabel('Cantidad de Casos', fontsize=17)
plt.title('Casos totales de Nuevo Leon vs Sinaloa', fontsize=17)
plt.show()

# %% [markdown]
# ### Conclusión pregunta 1. :
# #### Podemos observar claramente que los casos del Estado de Nuevo León son superiores a los de Sinaloa por bastante. Esto mismo nos lleva a la 2da pregunta:

# %% [markdown]
# ## Pregunta #2: Que diferencia hay entre la población de Nuevo León y de Sinaloa?

# %%
df['Habitantes'].plot(kind='hist')
plt.show()

# %% [markdown]
# ### Conclusión pregunta 2. :
# #### La población de Nuevo Leon es mucho mayor que la población de Sinaloa, por ello podemos entender el porque hay mayor numero de casos en Nuevo Leon

# %% [markdown]
# # 5. Problems you faced:
# #### Me costó trabajo poder filtrar la información necesaria para cada tipo de grafica y entender porque se generan algunos errores dentro del programa

# %% [markdown]
# # 6. Next steps to take:

# %%
#quiero que me promedie las defunciones de todos los estados. 
myPivot=pd.pivot_table(df,
                       index=['Estado'],
                       values=['Habitantes', 'Contagios las últimas dos semanas',
     'Defunciones las últimas dos semanas', 'Contagios Acumulados',
       'Defunciones Acumuladas'],
                       aggfunc=['mean'],
                      )
myPivot
# Out:
#                                                 mean  \
#                                 Contagios Acumulados
# Estado
# Aguascalientes                                 60559
# Baja California                               129391
# Baja California Sur                           100726
# Campeche                                       33309
# Chiapas                                        33617
# Chihuahua                                     123384
# Ciudad de México                             1356390
# Coahuila de Zaragoza                          143460
# Colima                                         54094
# Durango                                        67564
# Guanajuato                                    275296
# Guerrero                                       97186
# Hidalgo                                        88584
# Jalisco                                       231229
# Michoacán de Ocampo                            92732
# Morelos                                        65844
# México                                       5534086
# Nayarit                                        57541
# Nuevo León                                    307411
# Oaxaca                                        117040
# Puebla                                        166023
# Querétaro                                     139762
# Quintana Roo                                   90999
# San Luis Potosí                               179231
# Sinaloa                                       119209
# Sonora                                        161733
# Tabasco                                       189194
# Tamaulipas                                    140745
# Tlaxcala                                       42803
# Veracruz de Ignacio de la Llave               169773
# Yucatán                                       108277
# Zacatecas                                      67067
#
#                                                                    \
#                                 Contagios las últimas dos semanas
